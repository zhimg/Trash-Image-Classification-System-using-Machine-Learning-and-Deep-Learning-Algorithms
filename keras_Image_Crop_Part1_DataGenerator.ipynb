# %%
# %matplotlib inline
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set() 
from matplotlib import pyplot

# Data Processing 
import os
import os.path
import random
import PIL
import glob
from PIL import Image # to read images
#
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#For Keras model
import keras
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout, Flatten, Activation, BatchNormalization, Input
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from keras.preprocessing import image
import tensorflow as tf
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Dataset Preparation

# %%
path = "/content/drive/My Drive/"
annot = "/content/drive/My Drive/annotations.json"

# %%
# Read Annotations
with open(annot , 'r') as f:
    dataset = json.loads(f.read())

# %%
categories = dataset['categories']
anns = dataset['annotations']
imgs = dataset['images']
nr_cats = len(categories)
nr_annotations = len(anns)
nr_images = len(imgs)

print(nr_images) # Total Number of images
# Out:
# 1500

# %%
# category Dataframe and  Select 'six new Category(ouput classes)' for category Dataframe
cat_df = pd.DataFrame(categories)
keyValList = ['Cigarette','Clear plastic bottle','Drink can','Plastic straw','Glass bottle']
category_df = pd.DataFrame([d for d in categories if d['name'] in keyValList])

# Annotation Dataframe
ann_df = pd.DataFrame(anns)
# Images Dataframe
image_df = pd.DataFrame(imgs)

# %%
# Dropping unncessary columns for Keras fundamental CNN model
category_df = category_df.drop(['supercategory'], axis = 1)
image_df = image_df.drop(['license','flickr_url','coco_url','date_captured','flickr_640_url'], axis=1)
ann_df = ann_df.drop(['id'], axis=1)

# %%
merged_img_ann_df = pd.merge(left=image_df, right=ann_df, left_on='id', right_on='image_id')
final_merged_df = pd.merge(left=merged_img_ann_df, right=category_df, left_on='category_id', right_on='id') 
final_merged_df = final_merged_df.drop(['id_x','id_y','category_id','image_id','width','height'], axis = 1 )
final_merged_df = final_merged_df.rename(columns={"file_name": "filename", "name": "category"})
final_merged_df.head()
# Out:
#              filename  ...      category
# 0  batch_1/000006.jpg  ...  Glass bottle
# 1  batch_1/000012.jpg  ...  Glass bottle
# 2  batch_1/000048.jpg  ...  Glass bottle
# 3  batch_1/000021.jpg  ...  Glass bottle
# 4  batch_1/000022.jpg  ...  Glass bottle
#
# [5 rows x 6 columns]

# %%
# New Dataframe with selective columns
df = final_merged_df[['filename','bbox','category']]

# %%
# storing bounding box values as seperate columns
df = pd.concat([df , df['bbox'].apply(pd.Series)], axis = 1)
df.columns = ['filename','bbox','category', 'x_min','y_min','x_max', 'y_max'] # x_max : width and y_max : height
df = df.drop(['bbox',], axis=1)

# %%
df.head()
# Out:
#              filename      category  x_min   y_min  x_max   y_max
# 0  batch_1/000006.jpg  Glass bottle  517.0   127.0  447.0  1322.0
# 1  batch_1/000012.jpg  Glass bottle  379.0  1127.0  425.0   318.0
# 2  batch_1/000048.jpg  Glass bottle  211.0     1.0  417.0  1417.0
# 3  batch_1/000021.jpg  Glass bottle  852.0   638.0  687.0   291.0
# 4  batch_1/000022.jpg  Glass bottle  647.0  1033.0  820.0   376.0

# %%
# Calculate maximum x and maximum y points
df['x_max'] = df['x_max']+df['x_min']
df['y_max'] = df['y_max']+df['y_min']
# Convert float columns to integer
for col in  df.columns[2:]:
    df[col] = df[col].astype(int)

# %%
df['category'].value_counts().plot.bar()

# %% [markdown]
# Fetch, crop and store image data

# %%
# path of the folder containing the original images 
inPath = path+'data' 
# path of the folder that will contain the cropped image 
outPath = path+'trainDataTACO' 
train_data = []  
for ind in df.index:
  bbox = (df['x_min'][ind],df['y_min'][ind],df['x_max'][ind],df['y_max'][ind])
  imagePath = os.path.join(inPath+'/'+df['filename'][ind])
  img = Image.open(imagePath)
  img = img.crop(bbox)
  fullOutPath = os.path.join(outPath +'/'+df['filename'][ind]) 
  img.save(fullOutPath)

# %%
df = df.drop(['x_min','x_max','y_min','y_max'], axis=1)
df = df.astype({"category":'category'})
df.head()
# Out:
#              filename      category
# 0  batch_1/000006.jpg  Glass bottle
# 1  batch_1/000012.jpg  Glass bottle
# 2  batch_1/000048.jpg  Glass bottle
# 3  batch_1/000021.jpg  Glass bottle
# 4  batch_1/000022.jpg  Glass bottle

# %% [markdown]
# Data Split

# %%
# Data split Randomly
trainData_df, testData_df = train_test_split(df, test_size=0.20, random_state=41)

# %%
print(trainData_df.shape)
print(testData_df.shape)
# Out:
# (1153, 2)
# (289, 2)

# %%
trainData_df['category'].value_counts()
# Out:
# Cigarette               527
# Clear plastic bottle    235
# Drink can               180
# Plastic straw           123
# Glass bottle             88
# Name: category, dtype: int64

# %%
# Fixed for our 'Cigarette','Clear plastic bottle','Drink can','Plastic straw','Glass bottle' classes
NUM_CLASSES = 5
CHANNELS = 3

# Model parameters
IMAGE_RESIZE = 224
DENSE_LAYER_ACTIVATION = 'softmax'
OBJECTIVE_FUNCTION = 'categorical_crossentropy'
input_shape = (IMAGE_RESIZE,IMAGE_RESIZE,CHANNELS)

# EARLY_STOP_PATIENCE must be < NUM_EPOCHS
NUM_EPOCHS = 100
EARLY_STOP_PATIENCE = 50

# These steps value should be proper FACTOR of no.-of-images in train & valid folders respectively
# NOTE that these BATCH* are for Keras ImageDataGenerator batching to fill epoch step input
BATCH_SIZE_TRAINING = 50
BATCH_SIZE_VALIDATION = 50

# Using 1 to easily manage mapping between test_generator & prediction for submission preparation
BATCH_SIZE_TESTING = 1

# %%
# Batch Normalization helps in faster convergence
data_generator = ImageDataGenerator(validation_split=0.10, rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
# Train image data generator
# Create new train folder directory which should have images
newPath = path +'trainDataTACO'
train_generator=data_generator.flow_from_dataframe(
    dataframe=trainData_df,
    directory=newPath,
    x_col="filename",
    y_col="category",
    subset="training",
    batch_size=BATCH_SIZE_TRAINING,
    seed=41,
    shuffle=True,
    class_mode="categorical",
    target_size=(IMAGE_RESIZE,IMAGE_RESIZE)
)
# Out:
# Found 1038 validated image filenames belonging to 5 classes.

# %%
# Validation image data generator
validation_generator=data_generator.flow_from_dataframe(
    dataframe=trainData_df,
    directory=newPath,
    x_col="filename",
    y_col="category",
    subset="validation",
    batch_size=BATCH_SIZE_VALIDATION,
    seed=41,
    shuffle=True,
    class_mode="categorical",
    target_size=(IMAGE_RESIZE,IMAGE_RESIZE)
)
# Out:
# Found 115 validated image filenames belonging to 5 classes.

# %%
# These steps value should be proper FACTOR of no.-of-images in train & valid folders respectively
# Training images processed in each step would be no.-of-train-images / STEPS_PER_EPOCH_TRAINING
STEPS_PER_EPOCH_TRAINING = train_generator.n//train_generator.batch_size
STEPS_PER_EPOCH_VALIDATION =  validation_generator.n//validation_generator.batch_size

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation=DENSE_LAYER_ACTIVATION))

# %%
#Model Summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 222, 222, 32)      128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 109, 109, 64)      256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 52, 52, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 86528)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               44302848
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 44,401,605
# Trainable params: 44,400,133
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
sgd = optimizers.SGD(lr = 0.01, decay = 1e-6, momentum = 0.9, nesterov = True)
model.compile(optimizer = sgd, loss = OBJECTIVE_FUNCTION, metrics = ['accuracy'])

# %%
cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE)

# %%
fit_history = model.fit_generator(
        train_generator,
        steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
        epochs = NUM_EPOCHS,
        validation_data = validation_generator,
        validation_steps = STEPS_PER_EPOCH_VALIDATION,
        callbacks = [cb_early_stopper]
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 17s 868ms/step - loss: 2.2846 - accuracy: 0.3451 - val_loss: 8.0893 - val_accuracy: 0.4300
# Epoch 2/100
# 20/20 [==============================] - 16s 800ms/step - loss: 1.5741 - accuracy: 0.4636 - val_loss: 9.8009 - val_accuracy: 0.5077
# Epoch 3/100
# 20/20 [==============================] - 15s 741ms/step - loss: 1.4855 - accuracy: 0.5030 - val_loss: 7.0662 - val_accuracy: 0.4462
# Epoch 4/100
# 20/20 [==============================] - 16s 806ms/step - loss: 1.4313 - accuracy: 0.5304 - val_loss: 4.1025 - val_accuracy: 0.4800
# Epoch 5/100
# 20/20 [==============================] - 16s 804ms/step - loss: 1.3904 - accuracy: 0.5374 - val_loss: 3.6620 - val_accuracy: 0.4154
# Epoch 6/100
# 20/20 [==============================] - 14s 713ms/step - loss: 1.4306 - accuracy: 0.5324 - val_loss: 1.9173 - val_accuracy: 0.4462
# Epoch 7/100
# 20/20 [==============================] - 16s 814ms/step - loss: 1.3127 - accuracy: 0.5526 - val_loss: 2.7550 - val_accuracy: 0.5000
# Epoch 8/100
# 20/20 [==============================] - 16s 797ms/step - loss: 1.3658 - accuracy: 0.5230 - val_loss: 2.4481 - val_accuracy: 0.3846
# Epoch 9/100
# 20/20 [==============================] - 14s 694ms/step - loss: 1.2308 - accuracy: 0.5605 - val_loss: 1.3885 - val_accuracy: 0.5077
# Epoch 10/100
# 20/20 [==============================] - 16s 787ms/step - loss: 1.3325 - accuracy: 0.5620 - val_loss: 1.6057 - val_accuracy: 0.4700
# Epoch 11/100
# 20/20 [==============================] - 15s 762ms/step - loss: 1.1789 - accuracy: 0.5922 - val_loss: 2.1627 - val_accuracy: 0.4462
# Epoch 12/100
# 20/20 [==============================] - 14s 718ms/step - loss: 1.2688 - accuracy: 0.5719 - val_loss: 1.7773 - val_accuracy: 0.5231
# Epoch 13/100
# 20/20 [==============================] - 16s 800ms/step - loss: 1.2065 - accuracy: 0.5760 - val_loss: 2.6706 - val_accuracy: 0.4300
# Epoch 14/100
# 20/20 [==============================] - 15s 768ms/step - loss: 1.1956 - accuracy: 0.5881 - val_loss: 1.7111 - val_accuracy: 0.4769
# Epoch 15/100
# 20/20 [==============================] - 14s 703ms/step - loss: 1.2036 - accuracy: 0.5890 - val_loss: 1.4132 - val_accuracy: 0.4769
# Epoch 16/100
# 20/20 [==============================] - 15s 771ms/step - loss: 1.1633 - accuracy: 0.5779 - val_loss: 1.5516 - val_accuracy: 0.5100
# Epoch 17/100
# 20/20 [==============================] - 15s 768ms/step - loss: 1.1772 - accuracy: 0.6014 - val_loss: 2.0072 - val_accuracy: 0.4462
# Epoch 18/100
# 20/20 [==============================] - 14s 714ms/step - loss: 1.1479 - accuracy: 0.6190 - val_loss: 1.0515 - val_accuracy: 0.5385
# Epoch 19/100
# 20/20 [==============================] - 15s 762ms/step - loss: 1.1933 - accuracy: 0.5840 - val_loss: 1.9195 - val_accuracy: 0.3600
# Epoch 20/100
# 20/20 [==============================] - 15s 749ms/step - loss: 1.1824 - accuracy: 0.5953 - val_loss: 1.2127 - val_accuracy: 0.6154
# Epoch 21/100
# 20/20 [==============================] - 15s 727ms/step - loss: 1.1834 - accuracy: 0.5990 - val_loss: 1.3599 - val_accuracy: 0.5385
# Epoch 22/100
# 20/20 [==============================] - 15s 774ms/step - loss: 1.1347 - accuracy: 0.6053 - val_loss: 1.5179 - val_accuracy: 0.5100
# Epoch 23/100
# 20/20 [==============================] - 15s 773ms/step - loss: 1.0493 - accuracy: 0.6215 - val_loss: 1.5209 - val_accuracy: 0.5231
# Epoch 24/100
# 20/20 [==============================] - 14s 690ms/step - loss: 1.1096 - accuracy: 0.6306 - val_loss: 0.8701 - val_accuracy: 0.6000
# Epoch 25/100
# 20/20 [==============================] - 15s 748ms/step - loss: 1.1544 - accuracy: 0.6377 - val_loss: 1.1433 - val_accuracy: 0.5200
# Epoch 26/100
# 20/20 [==============================] - 16s 788ms/step - loss: 1.0452 - accuracy: 0.6390 - val_loss: 1.6137 - val_accuracy: 0.5231
# Epoch 27/100
# 20/20 [==============================] - 13s 672ms/step - loss: 1.0771 - accuracy: 0.6496 - val_loss: 1.3368 - val_accuracy: 0.5692
# Epoch 28/100
# 20/20 [==============================] - 15s 753ms/step - loss: 1.0996 - accuracy: 0.6417 - val_loss: 1.8746 - val_accuracy: 0.4600
# Epoch 29/100
# 20/20 [==============================] - 15s 752ms/step - loss: 1.0817 - accuracy: 0.6310 - val_loss: 1.6415 - val_accuracy: 0.5846
# Epoch 30/100
# 20/20 [==============================] - 14s 677ms/step - loss: 1.0542 - accuracy: 0.6437 - val_loss: 1.0008 - val_accuracy: 0.5538
# Epoch 31/100
# 20/20 [==============================] - 15s 762ms/step - loss: 1.1726 - accuracy: 0.5870 - val_loss: 2.2965 - val_accuracy: 0.4500
# Epoch 32/100
# 20/20 [==============================] - 14s 720ms/step - loss: 1.0897 - accuracy: 0.6260 - val_loss: 1.9980 - val_accuracy: 0.5846
# Epoch 33/100
# 20/20 [==============================] - 14s 710ms/step - loss: 1.1044 - accuracy: 0.6296 - val_loss: 1.5903 - val_accuracy: 0.4769
# Epoch 34/100
# 20/20 [==============================] - 15s 740ms/step - loss: 1.1030 - accuracy: 0.6164 - val_loss: 3.0696 - val_accuracy: 0.4300
# Epoch 35/100
# 20/20 [==============================] - 15s 767ms/step - loss: 1.1072 - accuracy: 0.6290 - val_loss: 1.7084 - val_accuracy: 0.6000
# Epoch 36/100
# 20/20 [==============================] - 14s 687ms/step - loss: 1.0711 - accuracy: 0.6265 - val_loss: 2.5765 - val_accuracy: 0.4154
# Epoch 37/100
# 20/20 [==============================] - 15s 749ms/step - loss: 1.0343 - accuracy: 0.6468 - val_loss: 2.6717 - val_accuracy: 0.4900
# Epoch 38/100
# 20/20 [==============================] - 15s 735ms/step - loss: 1.1043 - accuracy: 0.6377 - val_loss: 1.9769 - val_accuracy: 0.4769
# Epoch 39/100
# 20/20 [==============================] - 14s 708ms/step - loss: 1.0866 - accuracy: 0.6377 - val_loss: 3.2273 - val_accuracy: 0.4923
# Epoch 40/100
# 20/20 [==============================] - 15s 743ms/step - loss: 1.0598 - accuracy: 0.6589 - val_loss: 2.1259 - val_accuracy: 0.5200
# Epoch 41/100
# 20/20 [==============================] - 15s 752ms/step - loss: 1.0301 - accuracy: 0.6518 - val_loss: 1.2489 - val_accuracy: 0.5692
# Epoch 42/100
# 20/20 [==============================] - 14s 685ms/step - loss: 0.9919 - accuracy: 0.6680 - val_loss: 0.8031 - val_accuracy: 0.6154
# Epoch 43/100
# 20/20 [==============================] - 15s 754ms/step - loss: 0.9467 - accuracy: 0.6589 - val_loss: 1.8624 - val_accuracy: 0.5200
# Epoch 44/100
# 20/20 [==============================] - 15s 757ms/step - loss: 0.9853 - accuracy: 0.6640 - val_loss: 1.4869 - val_accuracy: 0.5231
# Epoch 45/100
# 20/20 [==============================] - 14s 684ms/step - loss: 0.9551 - accuracy: 0.6781 - val_loss: 1.7349 - val_accuracy: 0.6462
# Epoch 46/100
# 20/20 [==============================] - 15s 748ms/step - loss: 1.0644 - accuracy: 0.6498 - val_loss: 1.6366 - val_accuracy: 0.5500
# Epoch 47/100
# 20/20 [==============================] - 15s 753ms/step - loss: 0.9939 - accuracy: 0.6630 - val_loss: 1.3158 - val_accuracy: 0.5692
# Epoch 48/100
# 20/20 [==============================] - 14s 683ms/step - loss: 1.0018 - accuracy: 0.6680 - val_loss: 0.8576 - val_accuracy: 0.5846
# Epoch 49/100
# 20/20 [==============================] - 15s 747ms/step - loss: 0.9495 - accuracy: 0.6700 - val_loss: 1.4649 - val_accuracy: 0.5900
# Epoch 50/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.9348 - accuracy: 0.6940 - val_loss: 1.3250 - val_accuracy: 0.6615
# Epoch 51/100
# 20/20 [==============================] - 14s 678ms/step - loss: 0.9358 - accuracy: 0.6773 - val_loss: 1.0736 - val_accuracy: 0.5692
# Epoch 52/100
# 20/20 [==============================] - 15s 743ms/step - loss: 0.9921 - accuracy: 0.6630 - val_loss: 1.7620 - val_accuracy: 0.3900
# Epoch 53/100
# 20/20 [==============================] - 15s 754ms/step - loss: 0.8822 - accuracy: 0.7065 - val_loss: 1.5888 - val_accuracy: 0.4154
# Epoch 54/100
# 20/20 [==============================] - 13s 663ms/step - loss: 0.9194 - accuracy: 0.6913 - val_loss: 1.4273 - val_accuracy: 0.5846
# Epoch 55/100
# 20/20 [==============================] - 15s 740ms/step - loss: 0.9372 - accuracy: 0.6865 - val_loss: 1.1305 - val_accuracy: 0.5400
# Epoch 56/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.9751 - accuracy: 0.6650 - val_loss: 1.6571 - val_accuracy: 0.4769
# Epoch 57/100
# 20/20 [==============================] - 14s 685ms/step - loss: 0.9249 - accuracy: 0.6812 - val_loss: 1.3121 - val_accuracy: 0.6154
# Epoch 58/100
# 20/20 [==============================] - 15s 732ms/step - loss: 0.9161 - accuracy: 0.6852 - val_loss: 1.4626 - val_accuracy: 0.6100
# Epoch 59/100
# 20/20 [==============================] - 15s 738ms/step - loss: 0.9273 - accuracy: 0.6947 - val_loss: 2.5448 - val_accuracy: 0.3692
# Epoch 60/100
# 20/20 [==============================] - 14s 688ms/step - loss: 0.8827 - accuracy: 0.7014 - val_loss: 2.0220 - val_accuracy: 0.4308
# Epoch 61/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.9018 - accuracy: 0.6950 - val_loss: 2.1272 - val_accuracy: 0.3700
# Epoch 62/100
# 20/20 [==============================] - 15s 755ms/step - loss: 0.9461 - accuracy: 0.6883 - val_loss: 1.6080 - val_accuracy: 0.4923
# Epoch 63/100
# 20/20 [==============================] - 14s 679ms/step - loss: 0.9146 - accuracy: 0.6883 - val_loss: 0.8678 - val_accuracy: 0.5692
# Epoch 64/100
# 20/20 [==============================] - 16s 775ms/step - loss: 0.8862 - accuracy: 0.6913 - val_loss: 1.1241 - val_accuracy: 0.6000
# Epoch 65/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.8638 - accuracy: 0.6860 - val_loss: 1.4712 - val_accuracy: 0.6154
# Epoch 66/100
# 20/20 [==============================] - 14s 690ms/step - loss: 0.8719 - accuracy: 0.6998 - val_loss: 2.2437 - val_accuracy: 0.5846
# Epoch 67/100
# 20/20 [==============================] - 15s 747ms/step - loss: 0.8313 - accuracy: 0.7095 - val_loss: 1.3867 - val_accuracy: 0.6000
# Epoch 68/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.8253 - accuracy: 0.7105 - val_loss: 1.6662 - val_accuracy: 0.5385
# Epoch 69/100
# 20/20 [==============================] - 13s 661ms/step - loss: 0.8965 - accuracy: 0.7065 - val_loss: 1.4522 - val_accuracy: 0.7077
# Epoch 70/100
# 20/20 [==============================] - 15s 755ms/step - loss: 0.7918 - accuracy: 0.7115 - val_loss: 1.8154 - val_accuracy: 0.6500
# Epoch 71/100
# 20/20 [==============================] - 15s 739ms/step - loss: 0.8409 - accuracy: 0.7206 - val_loss: 1.2794 - val_accuracy: 0.6923
# Epoch 72/100
# 20/20 [==============================] - 14s 704ms/step - loss: 0.7839 - accuracy: 0.7330 - val_loss: 0.7367 - val_accuracy: 0.5538
# Epoch 73/100
# 20/20 [==============================] - 15s 750ms/step - loss: 0.8952 - accuracy: 0.6936 - val_loss: 1.1423 - val_accuracy: 0.6400
# Epoch 74/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.8430 - accuracy: 0.7237 - val_loss: 1.4589 - val_accuracy: 0.6308
# Epoch 75/100
# 20/20 [==============================] - 14s 685ms/step - loss: 0.8612 - accuracy: 0.7050 - val_loss: 2.2945 - val_accuracy: 0.5077
# Epoch 76/100
# 20/20 [==============================] - 15s 749ms/step - loss: 0.8210 - accuracy: 0.7136 - val_loss: 1.7578 - val_accuracy: 0.5900
# Epoch 77/100
# 20/20 [==============================] - 15s 751ms/step - loss: 0.7594 - accuracy: 0.7449 - val_loss: 1.4682 - val_accuracy: 0.6308
# Epoch 78/100
# 20/20 [==============================] - 14s 698ms/step - loss: 0.9092 - accuracy: 0.6994 - val_loss: 1.1587 - val_accuracy: 0.5692
# Epoch 79/100
# 20/20 [==============================] - 15s 751ms/step - loss: 0.8290 - accuracy: 0.7156 - val_loss: 1.2776 - val_accuracy: 0.5600
# Epoch 80/100
# 20/20 [==============================] - 15s 740ms/step - loss: 0.8167 - accuracy: 0.7156 - val_loss: 1.3472 - val_accuracy: 0.5692
# Epoch 81/100
# 20/20 [==============================] - 14s 680ms/step - loss: 0.8598 - accuracy: 0.7039 - val_loss: 2.8251 - val_accuracy: 0.5538
# Epoch 82/100
# 20/20 [==============================] - 15s 755ms/step - loss: 0.8011 - accuracy: 0.7230 - val_loss: 1.6677 - val_accuracy: 0.5700
# Epoch 83/100
# 20/20 [==============================] - 15s 752ms/step - loss: 0.7293 - accuracy: 0.7460 - val_loss: 0.8394 - val_accuracy: 0.6615
# Epoch 84/100
# 20/20 [==============================] - 14s 684ms/step - loss: 0.7938 - accuracy: 0.7257 - val_loss: 1.9170 - val_accuracy: 0.5692
# Epoch 85/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.7650 - accuracy: 0.7399 - val_loss: 1.5254 - val_accuracy: 0.4700
# Epoch 86/100
# 20/20 [==============================] - 15s 739ms/step - loss: 0.8223 - accuracy: 0.7287 - val_loss: 0.9463 - val_accuracy: 0.6462
# Epoch 87/100
# 20/20 [==============================] - 14s 703ms/step - loss: 0.8534 - accuracy: 0.6990 - val_loss: 1.6124 - val_accuracy: 0.4923
# Epoch 88/100
# 20/20 [==============================] - 15s 735ms/step - loss: 0.7827 - accuracy: 0.7193 - val_loss: 1.1701 - val_accuracy: 0.6400
# Epoch 89/100
# 20/20 [==============================] - 15s 757ms/step - loss: 0.7605 - accuracy: 0.7338 - val_loss: 1.8878 - val_accuracy: 0.4308
# Epoch 90/100
# 20/20 [==============================] - 14s 677ms/step - loss: 0.7787 - accuracy: 0.7247 - val_loss: 1.3448 - val_accuracy: 0.6000
# Epoch 91/100
# 20/20 [==============================] - 15s 744ms/step - loss: 0.7609 - accuracy: 0.7358 - val_loss: 1.4013 - val_accuracy: 0.5500
# Epoch 92/100
# 20/20 [==============================] - 15s 740ms/step - loss: 0.7854 - accuracy: 0.7389 - val_loss: 1.9791 - val_accuracy: 0.4308
# Epoch 93/100
# 20/20 [==============================] - 14s 688ms/step - loss: 0.6769 - accuracy: 0.7429 - val_loss: 0.6297 - val_accuracy: 0.6615
# Epoch 94/100
# 20/20 [==============================] - 15s 766ms/step - loss: 0.8232 - accuracy: 0.7270 - val_loss: 1.3128 - val_accuracy: 0.5800
# Epoch 95/100
# 20/20 [==============================] - 15s 746ms/step - loss: 0.7224 - accuracy: 0.7449 - val_loss: 1.0325 - val_accuracy: 0.6615
# Epoch 96/100
# 20/20 [==============================] - 14s 684ms/step - loss: 0.7897 - accuracy: 0.7156 - val_loss: 2.1700 - val_accuracy: 0.5231
# Epoch 97/100
# 20/20 [==============================] - 15s 737ms/step - loss: 0.7879 - accuracy: 0.7420 - val_loss: 2.1005 - val_accuracy: 0.3600
# Epoch 98/100
# 20/20 [==============================] - 15s 754ms/step - loss: 0.7667 - accuracy: 0.7336 - val_loss: 1.6975 - val_accuracy: 0.4769
# Epoch 99/100
# 20/20 [==============================] - 14s 689ms/step - loss: 0.7471 - accuracy: 0.7600 - val_loss: 2.0617 - val_accuracy: 0.4308
# Epoch 100/100
# 20/20 [==============================] - 15s 739ms/step - loss: 0.7608 - accuracy: 0.7387 - val_loss: 0.9625 - val_accuracy: 0.6200

# %%
# test image data generator
test_generator=data_generator.flow_from_dataframe(
    dataframe=testData_df,
    directory=newPath,
    x_col="filename",
    y_col=None,
    batch_size=BATCH_SIZE_TESTING,
    seed=41,
    shuffle=False,
    class_mode=None,
    target_size=(IMAGE_RESIZE,IMAGE_RESIZE)
)
# Out:
# Found 289 validated image filenames.

# %%
# Reset before each call to predict
test_generator.reset()

pred = model.predict_generator(test_generator, steps = len(test_generator), verbose = 1)
# Out:
# 289/289 [==============================] - 4s 15ms/step

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
sorting = (-pred).argsort()
# getting the top 5 predictions
sorted_ = sorting[0][:5]
# Prediction for all the classes
for value in sorted_:
  predicted_label = labels[value]
  # Rounding steps
  prob = (pred[0][value]) * 100
  prob = "%.2f" % round(prob,2)
  print("Prediction is that %s%% of Data belongs to %s." % (prob, predicted_label))
# Out:
# {0: 'Cigarette',
#  1: 'Clear plastic bottle',
#  2: 'Drink can',
#  3: 'Glass bottle',
#  4: 'Plastic straw'}

# %% [markdown]
# Used 'Adam' optimizer instead of SGD

# %%
model.compile(optimizer = 'adam', loss = OBJECTIVE_FUNCTION, metrics = ['accuracy'])

# %%
fit_history_adam = model.fit_generator(
        train_generator,
        steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
        epochs = NUM_EPOCHS,
        validation_data = validation_generator,
        validation_steps = STEPS_PER_EPOCH_VALIDATION,
        callbacks = [cb_early_stopper]
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 17s 869ms/step - loss: 1.4474 - accuracy: 0.5992 - val_loss: 2.2470 - val_accuracy: 0.6400
# Epoch 2/100
# 20/20 [==============================] - 16s 820ms/step - loss: 1.1848 - accuracy: 0.6154 - val_loss: 2.2126 - val_accuracy: 0.5692
# Epoch 3/100
# 20/20 [==============================] - 15s 732ms/step - loss: 1.1331 - accuracy: 0.6235 - val_loss: 1.0306 - val_accuracy: 0.5692
# Epoch 4/100
# 20/20 [==============================] - 16s 815ms/step - loss: 0.9950 - accuracy: 0.6530 - val_loss: 1.6603 - val_accuracy: 0.6600
# Epoch 5/100
# 20/20 [==============================] - 16s 810ms/step - loss: 0.9198 - accuracy: 0.6834 - val_loss: 1.5873 - val_accuracy: 0.5385
# Epoch 6/100
# 20/20 [==============================] - 15s 735ms/step - loss: 0.9725 - accuracy: 0.6872 - val_loss: 0.9467 - val_accuracy: 0.6462
# Epoch 7/100
# 20/20 [==============================] - 16s 818ms/step - loss: 0.8910 - accuracy: 0.7045 - val_loss: 1.5832 - val_accuracy: 0.6200
# Epoch 8/100
# 20/20 [==============================] - 16s 799ms/step - loss: 0.8475 - accuracy: 0.7095 - val_loss: 1.5604 - val_accuracy: 0.5692
# Epoch 9/100
# 20/20 [==============================] - 15s 740ms/step - loss: 0.8079 - accuracy: 0.7237 - val_loss: 0.7254 - val_accuracy: 0.6154
# Epoch 10/100
# 20/20 [==============================] - 16s 813ms/step - loss: 0.8574 - accuracy: 0.7000 - val_loss: 1.7680 - val_accuracy: 0.6500
# Epoch 11/100
# 20/20 [==============================] - 16s 791ms/step - loss: 0.7531 - accuracy: 0.7439 - val_loss: 1.2460 - val_accuracy: 0.6000
# Epoch 12/100
# 20/20 [==============================] - 15s 744ms/step - loss: 0.7934 - accuracy: 0.7295 - val_loss: 1.8488 - val_accuracy: 0.6154
# Epoch 13/100
# 20/20 [==============================] - 16s 781ms/step - loss: 0.7709 - accuracy: 0.7358 - val_loss: 1.1955 - val_accuracy: 0.6300
# Epoch 14/100
# 20/20 [==============================] - 16s 809ms/step - loss: 0.7905 - accuracy: 0.7247 - val_loss: 1.3676 - val_accuracy: 0.6769
# Epoch 15/100
# 20/20 [==============================] - 15s 744ms/step - loss: 0.7855 - accuracy: 0.7290 - val_loss: 1.0362 - val_accuracy: 0.6923
# Epoch 16/100
# 20/20 [==============================] - 16s 789ms/step - loss: 0.7725 - accuracy: 0.7257 - val_loss: 1.3350 - val_accuracy: 0.6600
# Epoch 17/100
# 20/20 [==============================] - 16s 783ms/step - loss: 0.7429 - accuracy: 0.7389 - val_loss: 0.7911 - val_accuracy: 0.6615
# Epoch 18/100
# 20/20 [==============================] - 15s 728ms/step - loss: 0.7279 - accuracy: 0.7399 - val_loss: 0.6614 - val_accuracy: 0.5692
# Epoch 19/100
# 20/20 [==============================] - 16s 798ms/step - loss: 0.7322 - accuracy: 0.7399 - val_loss: 1.2228 - val_accuracy: 0.6100
# Epoch 20/100
# 20/20 [==============================] - 16s 804ms/step - loss: 0.7032 - accuracy: 0.7520 - val_loss: 0.9946 - val_accuracy: 0.7538
# Epoch 21/100
# 20/20 [==============================] - 15s 739ms/step - loss: 0.7312 - accuracy: 0.7581 - val_loss: 2.0753 - val_accuracy: 0.6308
# Epoch 22/100
# 20/20 [==============================] - 16s 807ms/step - loss: 0.6493 - accuracy: 0.7650 - val_loss: 1.0528 - val_accuracy: 0.6600
# Epoch 23/100
# 20/20 [==============================] - 16s 776ms/step - loss: 0.6886 - accuracy: 0.7642 - val_loss: 1.3760 - val_accuracy: 0.6769
# Epoch 24/100
# 20/20 [==============================] - 14s 705ms/step - loss: 0.6795 - accuracy: 0.7582 - val_loss: 1.2131 - val_accuracy: 0.6923
# Epoch 25/100
# 20/20 [==============================] - 16s 793ms/step - loss: 0.6636 - accuracy: 0.7580 - val_loss: 1.4184 - val_accuracy: 0.5900
# Epoch 26/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.6700 - accuracy: 0.7611 - val_loss: 1.3086 - val_accuracy: 0.6154
# Epoch 27/100
# 20/20 [==============================] - 14s 714ms/step - loss: 0.5817 - accuracy: 0.7961 - val_loss: 1.1519 - val_accuracy: 0.6923
# Epoch 28/100
# 20/20 [==============================] - 16s 775ms/step - loss: 0.6881 - accuracy: 0.7591 - val_loss: 0.7664 - val_accuracy: 0.7300
# Epoch 29/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.6349 - accuracy: 0.7702 - val_loss: 0.9934 - val_accuracy: 0.6154
# Epoch 30/100
# 20/20 [==============================] - 14s 714ms/step - loss: 0.5723 - accuracy: 0.7966 - val_loss: 1.2887 - val_accuracy: 0.6154
# Epoch 31/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.6354 - accuracy: 0.7743 - val_loss: 1.3401 - val_accuracy: 0.6100
# Epoch 32/100
# 20/20 [==============================] - 15s 769ms/step - loss: 0.6019 - accuracy: 0.7920 - val_loss: 1.1471 - val_accuracy: 0.6923
# Epoch 33/100
# 20/20 [==============================] - 14s 707ms/step - loss: 0.5777 - accuracy: 0.8026 - val_loss: 1.9602 - val_accuracy: 0.6615
# Epoch 34/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5779 - accuracy: 0.7844 - val_loss: 1.5215 - val_accuracy: 0.6600
# Epoch 35/100
# 20/20 [==============================] - 16s 785ms/step - loss: 0.6251 - accuracy: 0.7844 - val_loss: 1.4435 - val_accuracy: 0.6000
# Epoch 36/100
# 20/20 [==============================] - 14s 696ms/step - loss: 0.5870 - accuracy: 0.7996 - val_loss: 0.9446 - val_accuracy: 0.6769
# Epoch 37/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.6231 - accuracy: 0.7864 - val_loss: 1.5485 - val_accuracy: 0.6100
# Epoch 38/100
# 20/20 [==============================] - 15s 770ms/step - loss: 0.5574 - accuracy: 0.8077 - val_loss: 1.0100 - val_accuracy: 0.7538
# Epoch 39/100
# 20/20 [==============================] - 14s 687ms/step - loss: 0.6351 - accuracy: 0.7652 - val_loss: 0.7010 - val_accuracy: 0.6769
# Epoch 40/100
# 20/20 [==============================] - 15s 769ms/step - loss: 0.5978 - accuracy: 0.7874 - val_loss: 1.2962 - val_accuracy: 0.6400
# Epoch 41/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.5556 - accuracy: 0.7915 - val_loss: 1.2098 - val_accuracy: 0.6615
# Epoch 42/100
# 20/20 [==============================] - 14s 705ms/step - loss: 0.5625 - accuracy: 0.7814 - val_loss: 1.1046 - val_accuracy: 0.6462
# Epoch 43/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5564 - accuracy: 0.8006 - val_loss: 1.5716 - val_accuracy: 0.6200
# Epoch 44/100
# 20/20 [==============================] - 16s 778ms/step - loss: 0.5612 - accuracy: 0.7976 - val_loss: 1.0546 - val_accuracy: 0.6462
# Epoch 45/100
# 20/20 [==============================] - 14s 713ms/step - loss: 0.5054 - accuracy: 0.8158 - val_loss: 1.3728 - val_accuracy: 0.6615
# Epoch 46/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.6108 - accuracy: 0.7874 - val_loss: 1.2331 - val_accuracy: 0.6400
# Epoch 47/100
# 20/20 [==============================] - 16s 790ms/step - loss: 0.5902 - accuracy: 0.8060 - val_loss: 1.3437 - val_accuracy: 0.6923
# Epoch 48/100
# 20/20 [==============================] - 14s 713ms/step - loss: 0.5326 - accuracy: 0.8135 - val_loss: 0.3843 - val_accuracy: 0.7077
# Epoch 49/100
# 20/20 [==============================] - 15s 767ms/step - loss: 0.5426 - accuracy: 0.8210 - val_loss: 1.2336 - val_accuracy: 0.6400
# Epoch 50/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.6069 - accuracy: 0.7723 - val_loss: 1.0760 - val_accuracy: 0.6923
# Epoch 51/100
# 20/20 [==============================] - 14s 702ms/step - loss: 0.5840 - accuracy: 0.7925 - val_loss: 1.1663 - val_accuracy: 0.6615
# Epoch 52/100
# 20/20 [==============================] - 16s 782ms/step - loss: 0.5322 - accuracy: 0.7992 - val_loss: 1.2301 - val_accuracy: 0.7100
# Epoch 53/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.5196 - accuracy: 0.8220 - val_loss: 1.4274 - val_accuracy: 0.6000
# Epoch 54/100
# 20/20 [==============================] - 14s 706ms/step - loss: 0.6037 - accuracy: 0.7838 - val_loss: 0.7487 - val_accuracy: 0.7231
# Epoch 55/100
# 20/20 [==============================] - 16s 782ms/step - loss: 0.5588 - accuracy: 0.8067 - val_loss: 1.3694 - val_accuracy: 0.6300
# Epoch 56/100
# 20/20 [==============================] - 16s 796ms/step - loss: 0.5077 - accuracy: 0.8110 - val_loss: 1.2005 - val_accuracy: 0.6462
# Epoch 57/100
# 20/20 [==============================] - 14s 707ms/step - loss: 0.5191 - accuracy: 0.8107 - val_loss: 1.0623 - val_accuracy: 0.6000
# Epoch 58/100
# 20/20 [==============================] - 15s 752ms/step - loss: 0.5440 - accuracy: 0.8117 - val_loss: 0.9635 - val_accuracy: 0.6900
# Epoch 59/100
# 20/20 [==============================] - 15s 768ms/step - loss: 0.4718 - accuracy: 0.8330 - val_loss: 1.5005 - val_accuracy: 0.5692
# Epoch 60/100
# 20/20 [==============================] - 14s 694ms/step - loss: 0.5304 - accuracy: 0.8030 - val_loss: 0.8171 - val_accuracy: 0.6462
# Epoch 61/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.4812 - accuracy: 0.8249 - val_loss: 1.0307 - val_accuracy: 0.6800
# Epoch 62/100
# 20/20 [==============================] - 15s 749ms/step - loss: 0.4998 - accuracy: 0.8128 - val_loss: 1.4958 - val_accuracy: 0.5385
# Epoch 63/100
# 20/20 [==============================] - 14s 705ms/step - loss: 0.5044 - accuracy: 0.8148 - val_loss: 1.1174 - val_accuracy: 0.5692
# Epoch 64/100
# 20/20 [==============================] - 15s 759ms/step - loss: 0.5332 - accuracy: 0.8138 - val_loss: 1.2505 - val_accuracy: 0.6800
# Epoch 65/100
# 20/20 [==============================] - 15s 755ms/step - loss: 0.5243 - accuracy: 0.8158 - val_loss: 2.0165 - val_accuracy: 0.4615
# Epoch 66/100
# 20/20 [==============================] - 14s 702ms/step - loss: 0.6258 - accuracy: 0.7713 - val_loss: 1.6660 - val_accuracy: 0.5692
# Epoch 67/100
# 20/20 [==============================] - 15s 748ms/step - loss: 0.5384 - accuracy: 0.8138 - val_loss: 1.2646 - val_accuracy: 0.6400
# Epoch 68/100
# 20/20 [==============================] - 15s 765ms/step - loss: 0.5097 - accuracy: 0.8128 - val_loss: 1.0354 - val_accuracy: 0.7077
# Epoch 69/100
# 20/20 [==============================] - 14s 701ms/step - loss: 0.5421 - accuracy: 0.8158 - val_loss: 0.9083 - val_accuracy: 0.6000
# Epoch 70/100
# 20/20 [==============================] - 16s 784ms/step - loss: 0.5354 - accuracy: 0.8050 - val_loss: 1.2210 - val_accuracy: 0.7000
# Epoch 71/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.5114 - accuracy: 0.8115 - val_loss: 1.0171 - val_accuracy: 0.6923
# Epoch 72/100
# 20/20 [==============================] - 14s 697ms/step - loss: 0.4757 - accuracy: 0.8249 - val_loss: 1.1385 - val_accuracy: 0.5846
# Epoch 73/100
# 20/20 [==============================] - 15s 771ms/step - loss: 0.5318 - accuracy: 0.8130 - val_loss: 0.9327 - val_accuracy: 0.7300
# Epoch 74/100
# 20/20 [==============================] - 15s 774ms/step - loss: 0.4578 - accuracy: 0.8289 - val_loss: 1.2584 - val_accuracy: 0.6615
# Epoch 75/100
# 20/20 [==============================] - 14s 697ms/step - loss: 0.5030 - accuracy: 0.8229 - val_loss: 1.0391 - val_accuracy: 0.6615
# Epoch 76/100
# 20/20 [==============================] - 15s 747ms/step - loss: 0.5002 - accuracy: 0.8229 - val_loss: 1.4411 - val_accuracy: 0.6100
# Epoch 77/100
# 20/20 [==============================] - 15s 764ms/step - loss: 0.4763 - accuracy: 0.8320 - val_loss: 1.6762 - val_accuracy: 0.5231
# Epoch 78/100
# 20/20 [==============================] - 14s 701ms/step - loss: 0.5038 - accuracy: 0.8158 - val_loss: 0.4156 - val_accuracy: 0.7692
# Epoch 79/100
# 20/20 [==============================] - 16s 785ms/step - loss: 0.4749 - accuracy: 0.8229 - val_loss: 1.2755 - val_accuracy: 0.6500
# Epoch 80/100
# 20/20 [==============================] - 16s 787ms/step - loss: 0.4881 - accuracy: 0.8240 - val_loss: 1.2061 - val_accuracy: 0.6462
# Epoch 81/100
# 20/20 [==============================] - 14s 714ms/step - loss: 0.4960 - accuracy: 0.8067 - val_loss: 0.7487 - val_accuracy: 0.6615
# Epoch 82/100
# 20/20 [==============================] - 16s 781ms/step - loss: 0.4812 - accuracy: 0.8229 - val_loss: 1.3988 - val_accuracy: 0.6600
# Epoch 83/100
# 20/20 [==============================] - 15s 772ms/step - loss: 0.4562 - accuracy: 0.8310 - val_loss: 0.9334 - val_accuracy: 0.6923
# Epoch 84/100
# 20/20 [==============================] - 14s 704ms/step - loss: 0.4444 - accuracy: 0.8300 - val_loss: 2.0659 - val_accuracy: 0.6615
# Epoch 85/100
# 20/20 [==============================] - 16s 775ms/step - loss: 0.4512 - accuracy: 0.8330 - val_loss: 1.0168 - val_accuracy: 0.6300
# Epoch 86/100
# 20/20 [==============================] - 16s 781ms/step - loss: 0.4786 - accuracy: 0.8219 - val_loss: 1.0296 - val_accuracy: 0.6615
# Epoch 87/100
# 20/20 [==============================] - 14s 693ms/step - loss: 0.4765 - accuracy: 0.8370 - val_loss: 1.1790 - val_accuracy: 0.6615
# Epoch 88/100
# 20/20 [==============================] - 15s 762ms/step - loss: 0.4671 - accuracy: 0.8411 - val_loss: 1.3305 - val_accuracy: 0.6200
# Epoch 89/100
# 20/20 [==============================] - 16s 777ms/step - loss: 0.4718 - accuracy: 0.8289 - val_loss: 1.6380 - val_accuracy: 0.6000
# Epoch 90/100
# 20/20 [==============================] - 14s 709ms/step - loss: 0.4942 - accuracy: 0.8158 - val_loss: 1.2681 - val_accuracy: 0.6769
# Epoch 91/100
# 20/20 [==============================] - 15s 752ms/step - loss: 0.4400 - accuracy: 0.8391 - val_loss: 1.0005 - val_accuracy: 0.6500
# Epoch 92/100
# 20/20 [==============================] - 15s 755ms/step - loss: 0.4511 - accuracy: 0.8310 - val_loss: 1.1957 - val_accuracy: 0.6923
# Epoch 93/100
# 20/20 [==============================] - 14s 701ms/step - loss: 0.4322 - accuracy: 0.8472 - val_loss: 1.3188 - val_accuracy: 0.6769
# Epoch 94/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.4623 - accuracy: 0.8381 - val_loss: 1.2291 - val_accuracy: 0.6500
# Epoch 95/100
# 20/20 [==============================] - 15s 760ms/step - loss: 0.4411 - accuracy: 0.8512 - val_loss: 1.3898 - val_accuracy: 0.6769
# Epoch 96/100
# 20/20 [==============================] - 14s 694ms/step - loss: 0.4879 - accuracy: 0.8289 - val_loss: 1.1876 - val_accuracy: 0.6769
# Epoch 97/100
# 20/20 [==============================] - 15s 755ms/step - loss: 0.4629 - accuracy: 0.8150 - val_loss: 0.9248 - val_accuracy: 0.6000
# Epoch 98/100
# 20/20 [==============================] - 15s 763ms/step - loss: 0.4846 - accuracy: 0.8320 - val_loss: 1.5525 - val_accuracy: 0.6000

# %%
print(fit_history_adam.history.keys())
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plt.figure(1, figsize = (15,8)) 
    
plt.subplot(221)  
plt.plot(fit_history_adam.history['accuracy'])  
plt.plot(fit_history_adam.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 
    
plt.subplot(222)  
plt.plot(fit_history_adam.history['loss'])  
plt.plot(fit_history_adam.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()

# %%
# Reset before each call to predict
test_generator.reset()

pred = model.predict_generator(test_generator, steps = len(test_generator), verbose = 1)
# Out:
# 289/289 [==============================] - 4s 15ms/step

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
sorting = (-pred).argsort()
# getting the top 5 predictions
sorted_ = sorting[0][:5]
# Prediction for All the classes
for value in sorted_:
  predicted_label = labels[value]
  # Rounding steps
  prob = (pred[0][value]) * 100
  prob = "%.2f" % round(prob,2)
  print("Prediction is that %s%% of Data belongs to %s." % (prob, predicted_label))
# Out:
# Prediction is that 96.60% of Data belongs to Cigarette.
# Prediction is that 1.93% of Data belongs to Plastic straw.
# Prediction is that 0.72% of Data belongs to Clear plastic bottle.
# Prediction is that 0.56% of Data belongs to Drink can.
# Prediction is that 0.19% of Data belongs to Glass bottle.
